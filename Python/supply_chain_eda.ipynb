# %% [markdown]
# # Python Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("supply_chain_data.csv")

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.shape
# Out:
# (100, 24)

# %%
df.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %% [markdown]
# Checking Unique Values

# %%
df["Product type"].unique()
# Out:
# array(['haircare', 'skincare', 'cosmetics'], dtype=object)

# %%
df["Supplier name"].unique()
# Out:
# array(['Supplier 3', 'Supplier 1', 'Supplier 5', 'Supplier 4',
#        'Supplier 2'], dtype=object)

# %%
df["Transportation modes"].unique()
# Out:
# array(['Road', 'Air', 'Rail', 'Sea'], dtype=object)

# %%
df["Routes"].unique()
# Out:
# array(['Route B', 'Route C', 'Route A'], dtype=object)

# %%
# Rename Columns
df.columns = (
    df.columns
      .str.strip()
      .str.replace(" ", "_")
      .str.replace("-", "_")
)

# %%
df.columns
# Out:
# Index(['Product_type', 'SKU', 'Price', 'Availability',
#        'Number_of_products_sold', 'Revenue_generated', 'Customer_demographics',
#        'Stock_levels', 'Lead_times', 'Order_quantities', 'Shipping_times',
#        'Shipping_carriers', 'Shipping_costs', 'Supplier_name', 'Location',
#        'Lead_time', 'Production_volumes', 'Manufacturing_lead_time',
#        'Manufacturing_costs', 'Inspection_results', 'Defect_rates',
#        'Transportation_modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Product_type', 'SKU', 'Customer_demographics', 'Shipping_carriers',
#        'Supplier_name', 'Location', 'Inspection_results',
#        'Transportation_modes', 'Routes'],
#       dtype='object')

# %% [markdown]
# Business Features

# %%
# Profit Margin
df['Profit_Margin'] = (df['Revenue_generated'] - df['Manufacturing_costs']) / df['Revenue_generated']

# %%
# High / Low Revenue Category
df['Revenue_Category'] = df['Revenue_generated'].apply(
    lambda x: 'High' if x > df['Revenue_generated'].median() else 'Low'
)

# %%
# Shipping Efficiency
df['Shipping_Efficiency'] = df['Shipping_times'] / df['Lead_times']

# %%
df.to_csv("supply_chain_clean.csv", index=False)

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("supply_chain_clean.csv")

# %% [markdown]
# 1. Revenue Overview

# %%
# Total Revenue
df['Revenue_generated'].sum()
# Out:
# np.float64(577604.8187380086)

# %%
# Average Revenue per Product
df['Revenue_generated'].mean()
# Out:
# np.float64(5776.048187380086)

# %%
# Revenue Distribution
import matplotlib.pyplot as plt

plt.figure()
df['Revenue_generated'].hist()
plt.title("Revenue Distribution")
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 2. Product Analysis

# %%
#Top Product Types by Revenue
df.groupby('Product_type')['Revenue_generated'].sum().sort_values(ascending=False)
# Out:
# Product_type
# skincare     241628.162133
# haircare     174455.390605
# cosmetics    161521.265999
# Name: Revenue_generated, dtype: float64

# %%
# Product Count
df['Product_type'].value_counts()
# Out:
# Product_type
# skincare     40
# haircare     34
# cosmetics    26
# Name: count, dtype: int64

# %% [markdown]
#  3. Shipping Analysis

# %%
# Average Shipping Cost by Mode
df.groupby('Transportation_modes')['Shipping_costs'].mean()
# Out:
# Transportation_modes
# Air     6.017839
# Rail    5.469098
# Road    5.542115
# Sea     4.970294
# Name: Shipping_costs, dtype: float64

# %%
# Shipping Cost Distribution
df['Shipping_costs'].hist()
plt.title("Shipping Cost Distribution")
plt.show()

# %% [markdown]
# 4. Supplier Analysis

# %%
# Top Suppliers by Revenue
df.groupby('Supplier_name')['Revenue_generated'].sum().sort_values(ascending=False)
# Out:
# Supplier_name
# Supplier 1    157528.995039
# Supplier 2    125467.418605
# Supplier 5    110343.463656
# Supplier 3     97795.979638
# Supplier 4     86468.961799
# Name: Revenue_generated, dtype: float64

# %%
# Supplier vs Defect Rate
df.groupby('Supplier_name')['Defect_rates'].mean()
# Out:
# Supplier_name
# Supplier 1    1.803630
# Supplier 2    2.362750
# Supplier 3    2.465786
# Supplier 4    2.337397
# Supplier 5    2.665408
# Name: Defect_rates, dtype: float64

# %% [markdown]
# 5. Inventory Analysis

# %%
# Stock Levels
df['Stock_levels'].describe()
# Out:
# count    100.000000
# mean      47.770000
# std       31.369372
# min        0.000000
# 25%       16.750000
# 50%       47.500000
# 75%       73.000000
# max      100.000000
# Name: Stock_levels, dtype: float64

# %%
# Low Stock Products
df[df['Stock_levels'] < df['Stock_levels'].median()]
# Out:
#    Product_type    SKU      Price  Availability  Number_of_products_sold  \
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 6      skincare   SKU6   4.078333            48                       65
# 8     cosmetics   SKU8  68.717597            78                      150
# 9      skincare   SKU9  64.015733            35                      980
# 11     skincare  SKU11  90.635460            95                      960
# 15     skincare  SKU15  36.989245            94                      469
# 16     skincare  SKU16   7.547172            74                      280
# 17    cosmetics  SKU17  81.462534            82                      126
# 18     haircare  SKU18  36.443628            23                      620
# 20     skincare  SKU20  96.341072            22                      320
# ...

# %% [markdown]
# 6. Defect Analysis

# %%
# Average Defect Rate by Product
df.groupby('Product_type')['Defect_rates'].mean()
# Out:
# Product_type
# cosmetics    1.919287
# haircare     2.483150
# skincare     2.334681
# Name: Defect_rates, dtype: float64

# %% [markdown]
# 7. Correlation Analysis

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Insight: Strong correlation exists between shipping cost and lead time, indicating logistics inefficiency impacts cost.

# %%
# Top 5 Products by Revenue (BEST one to add)
import matplotlib.pyplot as plt

top_products = df.groupby('Product_type')['Revenue_generated'] \
                  .sum() \
                  .sort_values(ascending=False) \
                  .head(5)

plt.figure(figsize=(8,5))
top_products.plot(kind='bar')

plt.title("Top 5 Products by Revenue")
plt.ylabel("Revenue")
plt.xlabel("Product Type")
plt.xticks(rotation=45)
plt.show()

# %%
# Shipping Cost by Product Type
ship_cost = df.groupby('Product_type')['Shipping_costs'].mean()

plt.figure(figsize=(8,5))
ship_cost.plot(kind='bar')

plt.title("Average Shipping Cost by Product Type")
plt.ylabel("Shipping Cost")
plt.xlabel("Product Type")
plt.xticks(rotation=45)
plt.show()

# %%
# Defect Rate by Supplier
defect_rate = df.groupby('Supplier_name')['Defect_rates'].mean().sort_values(ascending=False).head(5)

plt.figure(figsize=(8,5))
defect_rate.plot(kind='bar')

plt.title("Top Suppliers by Defect Rate")
plt.ylabel("Defect Rate")
plt.xlabel("Supplier")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Business Insights
# 1. Revenue Performance
# Product types show significant variation in revenue contribution, with a few categories generating the majority of total revenue.
#
# 2. Top Products
# The top 5 products contribute a major share of revenue, indicating a strong dependency on limited high-performing products.
#
# 3. Supplier Performance
# Supplier performance varies in terms of revenue contribution and defect rates, indicating inconsistent supplier quality.
#
# 4. Logistics Efficiency
# Shipping costs differ across product types, suggesting variation in transportation and handling requirements.
#
# 5. Defect Analysis
# Certain suppliers show higher defect rates, which may impact product quality and customer satisfaction.
#
# 6. Inventory Insight
# Stock levels indicate potential overstocking in some products and low availability in others, highlighting scope for inventory optimization.
#
# 7. Overall Conclusion
# The supply chain shows opportunities for optimization in supplier selection, inventory management, and logistics cost reduction to improve overall efficiency and profitability.

# %%
df.columns
# Out:
# Index(['Product_type', 'SKU', 'Price', 'Availability',
#        'Number_of_products_sold', 'Revenue_generated', 'Customer_demographics',
#        'Stock_levels', 'Lead_times', 'Order_quantities', 'Shipping_times',
#        'Shipping_carriers', 'Shipping_costs', 'Supplier_name', 'Location',
#        'Lead_time', 'Production_volumes', 'Manufacturing_lead_time',
#        'Manufacturing_costs', 'Inspection_results', 'Defect_rates',
#        'Transportation_modes', 'Routes', 'Costs', 'Profit_Margin',
#        'Revenue_Category', 'Shipping_Efficiency'],
#       dtype='object')
